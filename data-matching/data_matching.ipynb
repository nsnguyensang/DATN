# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('/home/darkknight/real-estate-integration/prj-exam/schema-matching/output/final.csv', encoding='utf-8')
data = data.drop(["Unnamed: 0"], axis=1)
data
# Out:
#                                                    title  \
# 0      CHÍNH CHỦ CẦN BÁN CĂN NHÀ CHUNG CƯ MINI NGÕ TỰ...
# 1      BCONS POLYGON .Thanh toán Tiền mặt Chiết khấu ...
# 2      SỦ DỤNG CĂN HỘ CAO CẤP THỜI GIAN DÀI 48 NĂM VỚ...
# 3      BCONS POLYGON cập nhật rổ hàng giá bán liên tụ...
# 4      Cần bán căn hộ chung cư HUD3 Tây Nam Linh Đàm ...
# ...                                                  ...
# 26262            Căn hộ chung cư tại Hoàng Huy Commerce
# 26263  CĐT BÁN CẮT LỖ 100TR QUỸ CĂN NGOẠI GIAO 2-3PN ...
# 26264  CẮT LỖ CĂN 3PN 2VS GIÁ 2,57 TỶ, 2N 1VS GIÁ 1,7...
# 26265  BÁN CĂN HỘ CHUNG CƯ 1,5PN = 46,3M2 TẠI VINHOME...
# 26266  SỞ HỮU CĂN HỘ CAO CẤP TIÊU CHUẨN 5 SAO TRÊN MẶ...
#
#                                              description         price  \
# 0      - Chính chủ cần bán căn nhà Chung cư mini .\nĐ...  7.000000e+09
# 1                                                   None  1.700000e+09
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26267 entries, 0 to 26266
# Data columns (total 23 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   title          26267 non-null  object
#  1   description    26267 non-null  object
#  2   price          25262 non-null  float64
#  3   square         26267 non-null  object
#  4   type           26267 non-null  object
#  5   name_contact   24726 non-null  object
#  6   phone_contact  24726 non-null  object
#  7   date           26267 non-null  object
#  8   direct         18398 non-null  object
#  9   district       26267 non-null  object
#  10  province       26267 non-null  object
#  11  street         26267 non-null  object
#  12  ward           26267 non-null  object
#  13  floor          26267 non-null  object
#  14  juridical      18549 non-null  object
#  15  bedroom        25576 non-null  object
#  16  length         18549 non-null  object
# ...

# %%
data["description"]
# Out:
# 0        - Chính chủ cần bán căn nhà Chung cư mini .\nĐ...
# 1                                                     None
# 2        💥 CƠ HỘI ĐỊNH CƯ NGAY TẠI TRUNG TÂM THÀNH PHỐ ...
# 3                                                     None
# 4        Cần bán nhanh trong tháng căn hộ Hud 3 Tây Nam...
#                                ...
# 26262    Cơ hội cuối cùng sở hữu căn hộ Hoàng Huy Comme...
# 26263                                                 None
# 26264                                                 None
# 26265                                                 None
# 26266                                                 None
# Name: description, Length: 26267, dtype: object

# %%
data.columns
# Out:
# Index(['title', 'description', 'price', 'square', 'type', 'name_contact',
#        'phone_contact', 'date', 'direct', 'district', 'province', 'street',
#        'ward', 'floor', 'juridical', 'bedroom', 'length', 'width',
#        'link_image', 'url_page', 'kitchen', 'parking', 'terrace'],
#       dtype='object')

# %%
np.min(data["date"])
# Out:
# '01/01/2021'

# %%
from datetime import datetime
from datetime import date
datetime.strptime('01/01/2021', '%d/%m/%Y').date() - datetime.strptime('12/01/2021', '%d/%m/%Y').date()
# Out:
# datetime.timedelta(days=-11)

# %%
# %cd /home/darkknight/real-estate-integration/prj-exam/data-matching/lib-match
# Out:
# /home/darkknight/real-estate-integration/prj-exam/data-matching/lib-match

# %%
data["description"].fillna('None', inplace=True)
data["description"]
# Out:
# 0                                   Chính chủ cần bán nhà:
# 1        Cần bán 2 căn studio 36m2 giá 750tr,Vị Trí : K...
# 2        Chính chủ bán hoặc Cho thuê CHCC Him Lam, Quận...
# 3        MUA NGAY KẺO TIẾC:CĂN HỘ CAO CẤP VEN BIỂN NHA ...
# 4                                                     None
#                                ...
# 39814    Cơ hội cuối cùng sở hữu căn hộ Hoàng Huy Comme...
# 39815                                                 None
# 39816                                                 None
# 39817                                                 None
# 39818                                                 None
# Name: description, Length: 39819, dtype: object

# %%
# !python train_remove_duplicate.py

# %%
# !python execute_remove_duplicate.py
# Out:
# Original size 26267
# After remove duplicates size 25513
# Save final data

# %%
data = pd.read_csv('/home/darkknight/real-estate-integration/prj-exam/data-matching/final_data.csv', encoding='utf-8')
data
# Out:
#                                                    title  \
# 0                            Chính chủ bán gấp căn hộ q4
# 1          Bán căn hộ Gold View Full NT Q4 .1pn -2pn-3pn
# 2       Căn hộ Galaxy 9, 1 phòng ngủ, đã có sổ, view đẹp
# 3      Cần Bán căn hộ Gold View 81m2 full NT 3,900 triệu
# 4                  Bán 2 phòng ngủ Gold View giá cực mềm
# ...                                                  ...
# 25508    Dự án Khu đô thị Bình An Đức Hòa - The Win City
# 25509  SỞ HỮU NGAY CĂN HỘ THE WIN CITY NẰM TẠI MẶT TI...
# 25510  Bán căn hộ, DT 823, Đức Hòa, Long An, giá cực ...
# 25511  Mở Bán Chung Cư XPHomes Star Tân Tây Đô Quốc L...
# 25512  CHUNGCƯ MINI HỌC VIỆN TÀI CHÍNH – 6 TẦNG - 12 ...
#
#                                              description         price  \
# 0      Chính chủ bán gấp Căn hộ 2 PN, 2 WC , tầng cao...  3.250000e+09
# 1      2PN, DT 80m2 : Giá từ 3.8 tỷ - 4.2tỷ 2PN, DT 9...  3.350000e+09
# ...
