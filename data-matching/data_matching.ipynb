# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('C:/Workspace/DATN/schema-matching/output/final.csv', encoding='utf-8')
data = data.drop(["Unnamed: 0"], axis=1)
data
# Out:
#                                                    title  \
# 0      CẮT LỖ SÂU CĂN HỘ BIỂN HẠ LONG TẦNG CAO 1,2 TỶ...
# 1      Ngân hàng Siết bán gấp căn 4 ngủ Tháp V2 - The...
# 2      Bán căn hộ Cantavil An Phú căn góc 125m2 3PN f...
# 3      Cắt lỗ căn hộ 2PN 2WC 2ty050 West Gate ngay tr...
# 4      Bán căn hộ Hope Residence Phúc Đồng, 70m2, 2PN...
# ...                                                  ...
# 28263  Siêu hiếm nhà Chung cư 86m2, chỉ 2.7 tỷ, 3PN, ...
# 28264  BÁN NHANH vị trí siêu đẹp Chung Cư 80M2, 2PN, ...
# 28265  Nhà HXH Lũy Bán Bích 80m2, 4 tầng, 9 PN c...
# 28266  Cần bán Chung cư chính chủ tại Mỹ Đình DT 100m...
# 28267  Căn 2PN giá tốt view công viên nội khu Masteri...
#
#                                              description         price square  \
# 0      CẮT LỖ SÂU CĂN HỘ BIỂN HẠ LONG 1,2 TỶ/CĂN - 09...  0.000000e+00    NaN
# 1      Ngân hàng Siết bán gấp căn 4 ngủ Tháp V2 - The...  5.000000e+15   140m
# 2      Gia đình cần bán căn chung cư Cantavil Premier...  8.000000e+09   125m
# 3      Cần bán nhanh căn hộ West Gate Trung tâm hành ...  2.000000e+15    59m
# 4      Chủ nhà cần bán căn hộ chung cư Hope Residence...  2.000000e+09    70m
# ...                                                  ...           ...    ...
# 28263                                                NaN  2.700000e+09    86m
# 28264                                                NaN  2.800000e+09    80m
# 28265                                                NaN  7.700000e+09    80m
# 28266                                                NaN  4.500000e+09   100m
# 28267                                                NaN  3.850000e+09    74m
#
#                           type       name_contact phone_contact        date  \
# 0      Cần bán căn hộ chung cư          Trọng Tân    0965524396  14/06/2023
# 1      Cần bán căn hộ chung cư      Trần Huy Hiệp    0943609595  13/06/2023
# 2      Cần bán căn hộ chung cư     Nguyễn Đăng Hà    0912442669  06/05/2023
# 3      Cần bán căn hộ chung cư  Mai Thị Thanh Vân    0932660780  03/05/2023
# 4      Cần bán căn hộ chung cư    Phan Hoàng Phúc    0981043268  17/06/2023
# ...                        ...                ...           ...         ...
# 28263  Cần bán căn hộ chung cư                NaN           NaN  30/01/2021
# 28264  Cần bán căn hộ chung cư                NaN           NaN  30/01/2021
# 28265  Cần bán căn hộ chung cư                NaN           NaN  27/01/2021
# 28266  Cần bán căn hộ chung cư                NaN           NaN  30/01/2021
# 28267  Cần bán căn hộ chung cư                NaN           NaN  30/01/2021
#
#         direct     district  ... livingroom bathroom   pool garden  \
# 0         None      Hạ Long  ...       3 pk     2 wc  không  không
# 1         None      Hà Đông  ...       4 pk     4 wc  không  không
# 2         None            2  ...       0 pk     0 wc  không  không
# 3      Tây Nam   Bình Chánh  ...       2 pk     2 wc     có     có
# 4         None    Long Biên  ...       2 pk     2 wc  không  không
# ...        ...          ...  ...        ...      ...    ...    ...
# 28263     None  Nam Từ Liêm  ...        NaN     2 wc    NaN    NaN
# 28264     None  Nam Từ Liêm  ...        NaN     2 wc    NaN    NaN
# 28265     None      Tân Phú  ...        NaN     7 wc    NaN    NaN
# 28266     None  Nam Từ Liêm  ...        NaN     2 wc    NaN    NaN
# 28267     None            9  ...        NaN     2 wc    NaN    NaN
#
#                   project parking                            email kitchen  \
# 0            Pearl Villas     NaN            trongtanbds@gmail.com     NaN
# 1         Anland Lakeview     NaN  tranhuyhiep0986156450@gmail.com     NaN
# 2      Cantavil – Premier     NaN       nguyendangha1982@gmail.com     NaN
# 3          West Gate Park      có         maithanhvan311@gmail.com     NaN
# 4                    None     NaN       hoangphucphan102@gmail.com     NaN
# ...                   ...     ...                              ...     ...
# 28263                 NaN     NaN                              NaN     NaN
# 28264                 NaN     NaN                              NaN     NaN
# 28265                 NaN     NaN                              NaN     NaN
# 28266                 NaN     NaN                              NaN     NaN
# 28267                 NaN     NaN                              NaN     NaN
#
#       terrace                                            content
# 0         NaN                                                NaN
# 1         NaN                                                NaN
# 2         NaN                                                NaN
# 3         NaN                                                NaN
# 4         NaN                                                NaN
# ...       ...                                                ...
# 28263     NaN  Chính chủ cần bán gấp căn 86m2,- Pháp lý nhà: ...
# 28264     NaN  Dự án tọa lạc trên ô đất CT08 Khu Đô Thị The M...
# 28265     NaN  Diện tích nhà 80m2, dài 15m, nhà xây đủ,...
# 28266     NaN  Cần bán nhà chung cư sổ đỏ chính chủ diện tích...
# 28267     NaN  BÁN CĂN HỘ MASTERI CENTRE POINT TẦNG 3, TRUNG ...
#
# [28268 rows x 30 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28268 entries, 0 to 28267
# Data columns (total 30 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   title          28268 non-null  object
#  1   description    17091 non-null  object
#  2   price          28268 non-null  float64
#  3   square         28227 non-null  object
#  4   type           28268 non-null  object
#  5   name_contact   17134 non-null  object
#  6   phone_contact  9566 non-null   object
#  7   date           28268 non-null  object
#  8   direct         20412 non-null  object
#  9   district       28268 non-null  object
#  10  province       28268 non-null  object
#  11  street         28268 non-null  object
#  12  ward           28268 non-null  object
#  13  floor          28268 non-null  object
#  14  juridical      20412 non-null  object
#  15  bedroom        28268 non-null  object
#  16  length         9280 non-null   object
#  17  width          20412 non-null  object
#  18  link_image     28031 non-null  object
#  19  url_page       28268 non-null  object
#  20  livingroom     1376 non-null   object
#  21  bathroom       20364 non-null  object
#  22  pool           1376 non-null   object
#  23  garden         1376 non-null   object
#  24  project        9232 non-null   object
#  25  parking        7923 non-null   object
#  26  email          1376 non-null   object
#  27  kitchen        7904 non-null   object
#  28  terrace        7904 non-null   object
#  29  content        11132 non-null  object
# dtypes: float64(1), object(29)
# memory usage: 6.5+ MB

# %%
data["description"]
# Out:
# 0        CẮT LỖ SÂU CĂN HỘ BIỂN HẠ LONG 1,2 TỶ/CĂN - 09...
# 1        Ngân hàng Siết bán gấp căn 4 ngủ Tháp V2 - The...
# 2        Gia đình cần bán căn chung cư Cantavil Premier...
# 3        Cần bán nhanh căn hộ West Gate Trung tâm hành ...
# 4        Chủ nhà cần bán căn hộ chung cư Hope Residence...
#                                ...
# 28263                                                  NaN
# 28264                                                  NaN
# 28265                                                  NaN
# 28266                                                  NaN
# 28267                                                  NaN
# Name: description, Length: 28268, dtype: object

# %%
data.columns
# Out:
# Index(['title', 'description', 'price', 'square', 'type', 'name_contact',
#        'phone_contact', 'date', 'direct', 'district', 'province', 'street',
#        'ward', 'floor', 'juridical', 'bedroom', 'length', 'width',
#        'link_image', 'url_page', 'livingroom', 'bathroom', 'pool', 'garden',
#        'project', 'parking', 'email', 'kitchen', 'terrace', 'content'],
#       dtype='object')

# %%
np.min(data["date"])
# Out:
# '01/01/2021'

# %%
from datetime import datetime
from datetime import date
datetime.strptime('01/01/2021', '%d/%m/%Y').date() - datetime.strptime('12/01/2021', '%d/%m/%Y').date()
# Out:
# datetime.timedelta(days=-11)

# %%
# %cd /home/darkknight/real-estate-integration/prj-exam/data-matching/lib-match
# Out:
# /home/darkknight/real-estate-integration/prj-exam/data-matching/lib-match

# %%
data["description"].fillna('None', inplace=True)
data["description"]
# Out:
# 0                                   Chính chủ cần bán nhà:
# 1        Cần bán 2 căn studio 36m2 giá 750tr,Vị Trí : K...
# 2        Chính chủ bán hoặc Cho thuê CHCC Him Lam, Quận...
# 3        MUA NGAY KẺO TIẾC:CĂN HỘ CAO CẤP VEN BIỂN NHA ...
# 4                                                     None
#                                ...
# 39814    Cơ hội cuối cùng sở hữu căn hộ Hoàng Huy Comme...
# 39815                                                 None
# 39816                                                 None
# 39817                                                 None
# 39818                                                 None
# Name: description, Length: 39819, dtype: object

# %%
# !python train_remove_duplicate.py

# %%
# !python execute_remove_duplicate.py
# Out:
# Original size 26267
# After remove duplicates size 25513
# Save final data

# %%
data = pd.read_csv('/home/darkknight/real-estate-integration/prj-exam/data-matching/final_data.csv', encoding='utf-8')
data
# Out:
#                                                    title  \
# 0                            Chính chủ bán gấp căn hộ q4
# 1          Bán căn hộ Gold View Full NT Q4 .1pn -2pn-3pn
# 2       Căn hộ Galaxy 9, 1 phòng ngủ, đã có sổ, view đẹp
# 3      Cần Bán căn hộ Gold View 81m2 full NT 3,900 triệu
# 4                  Bán 2 phòng ngủ Gold View giá cực mềm
# ...                                                  ...
# 25508    Dự án Khu đô thị Bình An Đức Hòa - The Win City
# 25509  SỞ HỮU NGAY CĂN HỘ THE WIN CITY NẰM TẠI MẶT TI...
# 25510  Bán căn hộ, DT 823, Đức Hòa, Long An, giá cực ...
# 25511  Mở Bán Chung Cư XPHomes Star Tân Tây Đô Quốc L...
# 25512  CHUNGCƯ MINI HỌC VIỆN TÀI CHÍNH – 6 TẦNG - 12 ...
#
#                                              description         price  \
# 0      Chính chủ bán gấp Căn hộ 2 PN, 2 WC , tầng cao...  3.250000e+09
# 1      2PN, DT 80m2 : Giá từ 3.8 tỷ - 4.2tỷ 2PN, DT 9...  3.350000e+09
# 2      Cần bán căn hộ Galaxy 9, Nguyễn Khoái, Quận 4,...  2.700000e+09
# 3      Căn hộ cao cấp The Gold View nằm mặt tiền Bến ...  3.950000e+09
# 4      Chủ nhà gửi bán căn hộ 2 phòng ngủ Gold View: ...  3.700000e+09
# ...                                                  ...           ...
# 25508                                               None  1.000000e+09
# 25509  "Dự án chung cư giá rẻ dành riêng cho phân khú...  1.000000e+09
# 25510                                               None  2.250000e+07
# 25511  XP HOME TÂN TÂY ĐÔ\nChỉ từ 700TR sở hữu ngay c...  1.290000e+09
# 25512  CHUNG CƯ MINI HỌC VIỆN TÀI CHÍNH – 6 TẦNG - 12...  4.899000e+09
#
#        square     name_contact phone_contact        date    direct  \
# 0         0 m              NaN           NaN  25/03/2022      Đông
# 1         0 m              NaN           NaN  22/03/2022      Đông
# 2         0 m              NaN           NaN  22/03/2022       Bắc
# 3         0 m              NaN           NaN  22/03/2022  Đông Bắc
# 4         0 m              NaN           NaN  22/03/2022      Đông
# ...       ...              ...           ...         ...       ...
# 25508    65 m    Ngô Kim Phụng  0901.907.XXX  16/06/2022      None
# 25509    65 m    Ngô Kim Phụng    0901907148  18/06/2022       NaN
# 25510   120 m  Nguyễn Hồng Hải  0974.041.XXX  15/06/2022       Nam
# 25511    64 m       Sơn Nguyễn  0961.701.XXX  17/06/2022      None
# 25512    43 m    Trần Hoài Nam  0983.474.XXX  15/06/2022      None
#
#             street floor       juridical bedroom length width  \
# 0             None   0 t           Sổ đỏ    0 pn    0 m   0 m
# 1             None   0 t           Sổ đỏ    0 pn    0 m   0 m
# 2             None   0 t           Sổ đỏ    0 pn    0 m   0 m
# 3             None   0 t           Sổ đỏ    0 pn    0 m   0 m
# 4             None   0 t           Sổ đỏ    0 pn    0 m   0 m
# ...            ...   ...             ...     ...    ...   ...
# 25508   Tỉnh lộ 10   0 t  Sổ hồng/ Sổ đỏ    2 pn     0m    0m
# 25509   Tỉnh Lộ 10   1 t             NaN   2 pn     NaN   NaN
# 25510  Tỉnh lộ 823   1 t  Sổ hồng/ Sổ đỏ    2 pn    20m    6m
# 25511   Quốc lộ 32   0 t  Sổ hồng/ Sổ đỏ    3 pn     0m    0m
# 25512  Lê Văn Hiến   6 t  Sổ hồng/ Sổ đỏ   12 pn    10m  4,3m
#
#                                               link_image  \
# 0      https://nhadat24h.net.vn/storage/product/121/o...
# 1      https://nhadat24h.net.vn/storage/product/121/0...
# 2      https://nhadat24h.net.vn/storage/product/121/c...
# 3      https://nhadat24h.net.vn/storage/product/121/u...
# 4      https://nhadat24h.net.vn/storage/product/121/I...
# ...                                                  ...
# 25508                        https://alonhadat.com.vnnan
# 25509  https://bds123.cdn.static123.com/images/thumbs...
# 25510                        https://alonhadat.com.vnnan
# 25511  https://alonhadat.com.vn/files/properties/2022...
# 25512  https://alonhadat.com.vn/files/properties/2022...
#
#                                                 url_page kitchen parking  \
# 0      https://nhadat24h.net.vn/du-an/chinh-chu-ban-g...   Không   Không
# 1      https://nhadat24h.net.vn/du-an/ban-can-ho-gold...   Không   Không
# 2      https://nhadat24h.net.vn/du-an/can-ho-galaxy-9...   Không   Không
# 3      https://nhadat24h.net.vn/du-an/can-ban-can-ho-...   Không   Không
# 4      https://nhadat24h.net.vn/du-an/ban-2-phong-ngu...   Không   Không
# ...                                                  ...     ...     ...
# 25508  https://alonhadat.com.vn/du-an-the-win-city-du...      Có      Có
# 25509  https://bds123.vn/so-huu-can-ho-the-win-city-m...     NaN     NaN
# 25510  https://alonhadat.com.vn/ban-can-ho-dt-823-duc...      Có      Có
# 25511  https://alonhadat.com.vn/mo-ban-chung-cu-xphom...   Không   Không
# 25512  https://alonhadat.com.vn/chungcu-mini-hoc-vien...      Có      Có
#
#       terrace
# 0       Không
# 1       Không
# 2       Không
# 3       Không
# 4       Không
# ...       ...
# 25508      Có
# 25509     NaN
# 25510   Không
# 25511   Không
# 25512      Có
#
# [25513 rows x 19 columns]
